# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/rockyt07/data-center-dataset/Book1 (1).csv
# /kaggle/input/datasets/rockyt07/data-center-dataset/Book1.xlsx

# %%
df_gdcd=pd.read_csv("/kaggle/input/datasets/rockyt07/data-center-dataset/Book1 (1).csv")
df_gdcd.head(5)
# Out:
#           country  total_data_centers hyperscale_data_centers  \
# 0   United States                5426                    300+
# 1         Germany                 529                      50
# 2  United Kingdom                 523                      30
# 3           China                 449                     100
# 4          France                 322                      20
#
#   colocation_data_centers floor_space_sqft_total power_capacity_MW_total  \
# 0                 ~2,000+         ~3,552,000,000                ~12,000+
# 1                    ~200           ~350,000,000                 ~2,000+
# 2                    ~150           ~200,000,000                 ~1,000+
# 3                 ~1,000+           ~500,000,000                 ~8,000+
# 4                    ~110           ~120,000,000                    ~700
#
#   average_renewable_energy_usage_percent              tier_distribution  \
# 0                                   ~27%  I:5%, II:15%, III:60%, IV:20%
# 1                                   40%+        II:10%, III:70%, IV:20%
# 2                                   0.45        II:15%, III:70%, IV:15%
# 3                                   0.25        II:20%, III:60%, IV:20%
# 4                                   40%+        II:20%, III:70%, IV:10%
#
#                             key_operators  \
# 0  Equinix, Digital Realty, CoreSite, AWS
# 1      Equinix, Digital Realty, e-shelter
# 2              Equinix, Telehouse, Virtus
# 3     China Unicom, Tencent, Alibaba, GDS
# 4               Equinix, Interxion, Data4
#
#                             cloud_provider  ... avg_latency_to_global_hubs_ms  \
# 0  AWS:Yes, GCP:Yes, Azure:Yes, Oracle:Yes  ...                            40
# 1  AWS:Yes, GCP:Yes, Azure:Yes, Oracle:Yes  ...                            50
# 2  AWS:Yes, GCP:Yes, Azure:Yes, Oracle:Yes  ...                            40
# 3   AWS:Yes, GCP:No, Azure:Yes, Oracle:Yes  ...                            75
# 4  AWS:Yes, GCP:Yes, Azure:Yes, Oracle:Yes  ...                            50
#
#   number_of_fiber_connections growth_rate_of_data_centers_percent_per_year  \
# 0                         60+                                          12%
# 1                         30+                                           8%
# 2                         25+                                           7%
# 3                         40+                                          15%
# 4                         20+                                           6%
#
#   cooling_technologies_common  \
# 0      Air, Liquid, Immersion
# 1         Air, Indirect Evap.
# 2           Air, Free Cooling
# 3                 Air, Liquid
# 4                 Air, Liquid
#
#                      regulatory_challenges_or_limits  \
# 0  Power grid strain in VA, moratoriums in some s...
# 1          Power caps in Frankfurt, strict emissions
# 2                   Power grid constraints in London
# 3                  Power rationing in some provinces
# 4                    Power grid constraints in Paris
#
#        disaster_recovery_sites_common  \
# 0  Yes, especially for finance/health
# 1         Yes, especially for finance
# 2         Yes, especially for finance
# 3         Yes, for government/finance
# 4             Yes, for finance/health
#
#            green_dc_initiatives_description                  source_of_data  \
# 0  Solar, wind PPA, immersion cooling, LEED  Statista, Brightlio, IEA, CBRE
# 1          Wind, solar, carbon-neutral push             Statista, CBRE, IEA
# 2       Wind, solar, carbon-neutral targets             Statista, CBRE, IEA
# 3         Hydro, wind, solar, green finance             Statista, CBRE, IEA
# 4                  Wind, solar, PUE targets             Statista, CBRE, IEA
#
#   Unnamed: 19 Unnamed: 20
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 21 columns]

# %%
df_gdcd[df_gdcd['country']=='India']
# Out:
#    country  total_data_centers hyperscale_data_centers  \
# 13   India                  99                      10
#
#    colocation_data_centers floor_space_sqft_total power_capacity_MW_total  \
# 13                     ~50            ~50,000,000                    ~400
#
#    average_renewable_energy_usage_percent        tier_distribution  \
# 13                                   0.15  II:30%, III:60%, IV:10%
#
#                key_operators                           cloud_provider  ...  \
# 13  STT GDC, NTT, CtrlS, AWS  AWS:Yes, GCP:Yes, Azure:Yes, Oracle:Yes  ...
#
#    avg_latency_to_global_hubs_ms number_of_fiber_connections  \
# 13                           100                         15+
#
#    growth_rate_of_data_centers_percent_per_year cooling_technologies_common  \
# 13                                          18%                 Air, Liquid
#
#    regulatory_challenges_or_limits disaster_recovery_sites_common  \
# 13  Power supply, land acquisition               Yes, for BFSI/IT
#
#      green_dc_initiatives_description        source_of_data Unnamed: 19  \
# 13  Solar, wind, green building codes  Brightlio, CBRE, IEA         NaN
#
#    Unnamed: 20
# 13         NaN
#
# [1 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sc

# %%
df_gdcd.columns
# Out:
# Index(['country', 'total_data_centers', 'hyperscale_data_centers',
#        'colocation_data_centers', 'floor_space_sqft_total',
#        'power_capacity_MW_total', 'average_renewable_energy_usage_percent',
#        'tier_distribution', 'key_operators', 'cloud_provider',
#        'internet_penetration_percent', 'avg_latency_to_global_hubs_ms',
#        'number_of_fiber_connections',
#        'growth_rate_of_data_centers_percent_per_year',
#        'cooling_technologies_common', 'regulatory_challenges_or_limits',
#        'disaster_recovery_sites_common', 'green_dc_initiatives_description',
#        'source_of_data', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')

# %%
df_gdcd.isnull().sum()
# Out:
# country                                           0
# total_data_centers                                0
# hyperscale_data_centers                           0
# colocation_data_centers                           0
# floor_space_sqft_total                            0
# power_capacity_MW_total                           0
# average_renewable_energy_usage_percent            0
# tier_distribution                                12
# key_operators                                    21
# cloud_provider                                   42
# internet_penetration_percent                      0
# avg_latency_to_global_hubs_ms                     0
# number_of_fiber_connections                       0
# growth_rate_of_data_centers_percent_per_year      2
# cooling_technologies_common                       1
# regulatory_challenges_or_limits                   0
# disaster_recovery_sites_common                   13
# green_dc_initiatives_description                 26
# source_of_data                                    4
# Unnamed: 19                                     186
# Unnamed: 20                                     190
# dtype: int64

# %%
len(df_gdcd)
# Out:
# 191

# %%
# df_gdcd['hyperscale_data_centers'] = df_gdcd['hyperscale_data_centers'].astype(str).str.replace(r'\D+', '', regex=True)              #to convert the string 300+ and so on into only a numbered string
# df_gdcd['hyperscale_data_centers'] = df_gdcd['hyperscale_data_centers'].astype(int)   # to convert the string dataype column into integer

# %%
# df_gdcd["power_capacity_MW_total"] = (
#     df_gdcd["power_capacity_MW_total"]
#     .str.replace(r"[~, +]", "", regex=True)
#     .str.replace(",", "")
# )

# # Convert safely (invalid → NaN instead of error)
# df_gdcd["power_capacity_MW_total"] = pd.to_numeric(
#     df_gdcd["power_capacity_MW_total"], errors="coerce"
# )

# %%
cols=['colocation_data_centers','floor_space_sqft_total','power_capacity_MW_total','average_renewable_energy_usage_percent','number_of_fiber_connections','growth_rate_of_data_centers_percent_per_year','hyperscale_data_centers']
for col in cols:
    df_gdcd[col] = (
    df_gdcd[col]
    .str.replace(r"[~, +,%,<,>]", "", regex=True)
    .str.replace(",", "")
)

# Convert safely (invalid → NaN instead of error)
df_gdcd[col] = pd.to_numeric(
    df_gdcd[col], errors="coerce"
)

# %%
df_gdcd
# Out:
#             country  total_data_centers  hyperscale_data_centers  \
# 0     United States                5426                      300
# 1           Germany                 529                       50
# 2    United Kingdom                 523                       30
# 3             China                 449                      100
# 4            France                 322                       20
# ..              ...                 ...                      ...
# 186       Venezuela                   6                        0
# 187         Vietnam                  32                        1
# 188           Yemen                   1                        0
# 189          Zambia                   2                        0
# 190        Zimbabwe                   2                        0
#
#     colocation_data_centers floor_space_sqft_total power_capacity_MW_total  \
# 0                      2000             3552000000                   12000
# 1                       200              350000000                    2000
# 2                       150              200000000                    1000
# 3                      1000              500000000                    8000
# 4                       110              120000000                     700
# ..                      ...                    ...                     ...
# 186                       6                  50000                      20
# 187                      32                 450000                     145
# 188                       1                   8000                       0
# 189                       2                  15000                       3
# 190                       2                  16000                       5
#
#     average_renewable_energy_usage_percent  \
# 0                                       27
# 1                                       40
# 2                                     0.45
# 3                                     0.25
# 4                                       40
# ..                                     ...
# 186                                  44.00
# 187                                  80.70
# 188                                  45.00
# 189                                  33.00
# 190                                   3.00
#
#                                      tier_distribution  \
# 0                        I:5%, II:15%, III:60%, IV:20%
# 1                              II:10%, III:70%, IV:20%
# 2                              II:15%, III:70%, IV:15%
# 3                              II:20%, III:60%, IV:20%
# 4                              II:20%, III:70%, IV:10%
# ..                                                 ...
# 186                      Tier III (majority ISP-grade)
# 187              Tier III (majority) & growing Tier IV
# 188  PTC-YEMENNET (YemenNet-PTC), YemenMobile, Saba...
# 189                               Tier III (ISP-grade)
# 190  TelOne, Dandemutande, Econet/Cassava, NetOne, ...
#
#                                          key_operators  \
# 0               Equinix, Digital Realty, CoreSite, AWS
# 1                   Equinix, Digital Realty, e-shelter
# 2                           Equinix, Telehouse, Virtus
# 3                  China Unicom, Tencent, Alibaba, GDS
# 4                            Equinix, Interxion, Data4
# ..                                                 ...
# 186  CANTV, Movistar, Digitel, Inter, NetUno, Super...
# 187  Viettel IDC, VNPT, FPT Telecom, CMC Telecom, V...
# 188      No AWS/Azure/GCP region (cache/CDN labs only)
# 189  Airtel Zambia, MTN Zambia, Zamtel, Liquid Tele...
# 190      No AWS/Azure/GCP region (cache/CDN labs only)
#
#                                         cloud_provider  ...  \
# 0              AWS:Yes, GCP:Yes, Azure:Yes, Oracle:Yes  ...
# 1              AWS:Yes, GCP:Yes, Azure:Yes, Oracle:Yes  ...
# 2              AWS:Yes, GCP:Yes, Azure:Yes, Oracle:Yes  ...
# 3               AWS:Yes, GCP:No, Azure:Yes, Oracle:Yes  ...
# 4              AWS:Yes, GCP:Yes, Azure:Yes, Oracle:Yes  ...
# ..                                                 ...  ...
# 186           No AWS/Azure/GCP region (cache/lab only)  ...
# 187  No AWS/Azure/GCP region yet; Alibaba & Google ...  ...
# 188       No global hyperscale region (cache/lab only)  ...
# 189      No AWS/Azure/GCP region (cache/CDN labs only)  ...
# 190       No global hyperscale region (cache/lab only)  ...
#
#     avg_latency_to_global_hubs_ms number_of_fiber_connections  \
# 0                              40                          60
# 1                              50                          30
# 2                              40                          25
# 3                              75                          40
# 4                              50                          20
# ..                            ...                         ...
# 186                           120                           3
# 187                            58                           5
# 188                             1                           3
# 189                           120                           2
# 190                             3                        10.4
#
#     growth_rate_of_data_centers_percent_per_year  \
# 0                                             12
# 1                                              8
# 2                                              7
# 3                                             15
# 4                                              6
# ..                                           ...
# 186                                          300
# 187                                         1790
# 188                                            0
# 189                                          629
# 190                                            0
#
#                            cooling_technologies_common  \
# 0                               Air, Liquid, Immersion
# 1                                  Air, Indirect Evap.
# 2                                    Air, Free Cooling
# 3                                          Air, Liquid
# 4                                          Air, Liquid
# ..                                                 ...
# 186  Air cooling, UPS/gensets, precision AC in mode...
# 187  Air cooling, precision CRAC/CRAH, UPS/gensets,...
# 188  Air cooling, UPS/gensets, VSAT/Starlink backup...
# 189  Air cooling, UPS/gensets, VSAT/Starlink fallba...
# 190  Air cooling, UPS/gensets, precision AC, satell...
#
#                        regulatory_challenges_or_limits  \
# 0    Power grid strain in VA, moratoriums in some s...
# 1            Power caps in Frankfurt, strict emissions
# 2                     Power grid constraints in London
# 3                    Power rationing in some provinces
# 4                      Power grid constraints in Paris
# ..                                                 ...
# 186  Grid collapse & hyperinflation, power blackout...
# 187  Grid permitting delays, rural‑urban digital di...
# 188  Grid insecurity & airstrike risk, ISP monopoly...
# 189  Grid cost & affordability, load shedding, ISP ...
# 190  High internet cost, limited fixed broadband (7...
#
#                         disaster_recovery_sites_common  \
# 0                   Yes, especially for finance/health
# 1                          Yes, especially for finance
# 2                          Yes, especially for finance
# 3                          Yes, for government/finance
# 4                              Yes, for finance/health
# ..                                                 ...
# 186              1 (modern DR-capable colo in Caracas)
# 187              3+ (Hanoi, Ho Chi Minh City, Da Nang)
# 188  AAE‑1 cable landing at Aden, SEA‑ME‑WE‑5 via H...
# 189                0 (single edge sites, no formal DR)
# 190  GlobeNet submarine cable landing Maiquetía rou...
#
#                       green_dc_initiatives_description  \
# 0             Solar, wind PPA, immersion cooling, LEED
# 1                     Wind, solar, carbon-neutral push
# 2                  Wind, solar, carbon-neutral targets
# 3                    Hydro, wind, solar, green finance
# 4                             Wind, solar, PUE targets
# ..                                                 ...
# 186  Submarine cables (GlobeNet landing at Maiquetí...
# 187  Five submarine cables (APG, AAG, IA, SMW3/4), ...
# 188                                                NaN
# 189  EASSy via Mombasa terrestrial to Zambia, natio...
# 190                                                NaN
#
#                                         source_of_data Unnamed: 19 Unnamed: 20
# 0                       Statista, Brightlio, IEA, CBRE         NaN         NaN
# 1                                  Statista, CBRE, IEA         NaN         NaN
# 2                                  Statista, CBRE, IEA         NaN         NaN
# 3                                  Statista, CBRE, IEA         NaN         NaN
# 4                                  Statista, CBRE, IEA         NaN         NaN
# ..                                                 ...         ...         ...
# 186  DataReportal, Wikipedia, GlobeNet submarine op...         NaN         NaN
# 187  DataReportal, Tuoi Tre, Arizton, ISOC Pulse, V...         NaN         NaN
# 188  DataReportal, ISOC Pulse, Wikipedia, DataCente...         NaN         NaN
# 189  DataReportal, Statista, ISOC Pulse, Wikipedia,...         NaN         NaN
# 190  DataReportal, ISOC Pulse, Statista, DCD, TelOn...         NaN         NaN
#
# [191 rows x 21 columns]

# %%
df_gdcd['power_capacity_MW_total'].dtype
# Out:
# dtype('O')

# %%
df_gdcd['country']=df_gdcd['country'].astype("string")
df_gdcd['colocation_data_centers']=df_gdcd['colocation_data_centers'].astype("int64")
df_gdcd['floor_space_sqft_total']=df_gdcd['floor_space_sqft_total'].astype("int64")
# df_gdcd['average_renewable_energy_usage_percent']=df_gdcd['average_renewable_energy_usage_percent'].astype("int64")
# df_gdcd['internet_penetration_percent']=df_gdcd['internet_penetration_percent'].astype("int64")
# df_gdcd['avg_latency_to_global_hubs_ms']=df_gdcd['avg_latency_to_global_hubs_ms'].astype("int64")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_55/2100512228.py in <cell line: 0>()
#       1 df_gdcd['country']=df_gdcd['country'].astype("string")
#       2 df_gdcd['colocation_data_centers']=df_gdcd['colocation_data_centers'].astype("int64")
# ----> 3 df_gdcd['floor_space_sqft_total']=df_gdcd['floor_space_sqft_total'].astype("int64")
#       4 # df_gdcd['average_renewable_energy_usage_percent']=df_gdcd['average_renewable_energy_usage_percent'].astype("int64")
#       5 # df_gdcd['internet_penetration_percent']=df_gdcd['internet_penetration_percent'].astype("int64")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6663         else:
#    6664             # else, only a single dtype is given
# -> 6665             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     447             copy = False
#     448
# --> 449         return self.apply(
#     450             "astype",
#     451             dtype=dtype,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, using_cow, squeeze)
#     782             values = values[0, :]  # type: ignore[call-overload]
#     783
# --> 784         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     785
#     786         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     235
#     236     try:
# --> 237         new_values = astype_array(values, dtype, copy=copy)
#     238     except (ValueError, TypeError):
#     239         # e.g. _astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     180
#     181     else:
# --> 182         values = _astype_nansafe(values, dtype, copy=copy)
#     183
#     184     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in _astype_nansafe(arr, dtype, copy, skipna)
#     131     if copy or arr.dtype == object or dtype == object:
#     132         # Explicit copy, or required since NumPy can't view from / to object.
# --> 133         return arr.astype(dtype, copy=True)
#     134
#     135     return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'Unknown'

# %%
for col in df_gdcd.columns:
    print(col," type: ", df_gdcd[col].dtype,"\n")

# %%
df_sort=df_gdcd.sort_values('total_data_centers', ascending=False).iloc[:10]
df_sort.plot.bar(x='country', y='total_data_centers')

# %%
df_sort=df_gdcd.sort_values('hyperscale_data_centers', ascending=False).iloc[:10]
df_sort.plot.bar(x='country', y='hyperscale_data_centers')

# %%
import matplotlib.pyplot as plt
import math

# 1. Group the data by all three categories
grouped = df.groupby(['Year', 'Region', 'Model'])

# 2. Determine grid size (number of rows/cols)
num_plots = len(grouped)
cols = 3  # Adjust this to make the grid wider or thinner
rows = math.ceil(num_plots / cols)

# 3. Create a large figure to hold all subplots
fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 4))
axes = axes.flatten() # Flatten so we can iterate easily with a single index

# 4. Loop through the groups and plot
for i, ((year, region, model), group) in enumerate(grouped):
    ax = axes[i]
    
    # Sort by Month to ensure the line doesn't jump around
    group = group.sort_values('Month')
    
    ax.plot(group['Month'], group['Units_Sold'], marker='o', color='teal')
    
    # Customizing each subplot
    ax.set_title(f"{year} | {region} | {model}", fontsize=10)
    ax.set_xlabel('Month')
    ax.set_ylabel('Units Sold')
    ax.grid(True, linestyle='--', alpha=0.6)

# 5. Clean up: Remove any empty subplots at the end of the grid
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import interact, widgets

# --- 1. Setup the Update Function ---
def update_plot(region, model, year):
    # Filter the data based on dropdown selections
    filtered = df[(df['Region'] == region) & 
                  (df['Model'] == model) & 
                  (df['Year'] == year)]
    
    # Sort by month to ensure the line flows correctly
    filtered = filtered.sort_values('Month')

    # Clear the previous plot and create a new one
    plt.figure(figsize=(10, 5))
    
    if not filtered.empty:
        plt.plot(filtered['Month'], filtered['Units_Sold'], marker='o', color='tab:blue', linewidth=2)
        plt.title(f'Sales for {model} in {region} ({year})', fontsize=14)
        plt.xlabel('Month')
        plt.ylabel('Units Sold')
        plt.grid(True, linestyle='--', alpha=0.7)
        plt.xticks(range(1, 13)) # Assuming Months are 1-12
    else:
        plt.text(0.5, 0.5, 'No data available for this selection', 
                 horizontalalignment='center', verticalalignment='center')
        plt.title('No Data')
        
    plt.show()

# --- 2. Create the Widgets ---
# We use unique values from your columns to populate the dropdowns
region_dropdown = widgets.Dropdown(options=sorted(df['Region'].unique()), description='Region:')
model_dropdown = widgets.Dropdown(options=sorted(df['Model'].unique()), description='Model:')
year_dropdown = widgets.Dropdown(options=sorted(df['Year'].unique()), description='Year:')

# --- 3. Link Widgets to the Function ---
interact(update_plot, region=region_dropdown, model=model_dropdown, year=year_dropdown);

# %%
df1=df.groupby(['Region','Model'])['Units_Sold']
df1.head()
